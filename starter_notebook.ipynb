# %% [markdown]
# <a href="https://colab.research.google.com/github/luuthanhtruc/Assessment-2-Programming-Assignment/blob/main/starter_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏦 Project Overview
#
# Welcome to your **Smart Finance Assistant** development journey! This notebook will evolve from basic CSV processing to a complete AI-powered finance application.
#
# **Final Application Components:**
# - 💬 **AI Chat Interface** - Financial advice personality
# - 📊 **Data Analysis** - CSV transaction processing
# - 🔍 **RAG System** - Retrieval from financial documents
# - 🛠️ **Custom Tools** - Calculators and utilities
# - 🌐 **Gradio UI** - Professional web interface
#
# **Development Approach**: Build progressively from foundation to advanced features, using AI collaboration throughout.

# %% [markdown]
# ---
#
# # 🚀 Getting Started: Foundation Setup
#
# ## Initial Setup
# This cell installs the necessary libraries. In a Colab environment, you would uncomment the first line.

# %%
# Uncomment the line below when running in Google Colab
# !pip install gradio pandas hands-on-ai

# Import core libraries
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

print("📦 Core libraries loaded successfully!")
print(f"Pandas version: {pd.__version__}")
# Out:
# 📦 Core libraries loaded successfully!
# Pandas version: 2.2.2

# %% [markdown]
# ## Hands-on-AI Configuration
#
# Set up the hands-on-ai package for advanced features (chat, RAG, tools):

# %%
import os
from getpass import getpass

# Configure hands-on-ai server connection
os.environ['HANDS_ON_AI_SERVER'] = 'https://ollama.serveur.au'
os.environ['HANDS_ON_AI_MODEL'] = 'llama3.2'
os.environ['HANDS_ON_AI_API_KEY'] = getpass('Enter your API key: ')

print("🔑 Hands-on-AI configured successfully!")
# Out:
# Enter your API key: ··········
# 🔑 Hands-on-AI configured successfully!

# %% [markdown]
# The API key this semester is:  **isys2001-assignment-key**

# %% [markdown]
# ## Connection Test
#
# Test that everything is working correctly:

# %%
from hands_on_ai.chat import get_response

try:
    print("🔄 Connecting to AI...\n")

    response = get_response(
        "Hello! I'm building a Smart Finance Assistant."
    )

    if "Error" in str(response):

        print("⚠️ AI unavailable — switching to offline mode.\n")

        response = """
💡 Smart Finance Assistant

• Spending analysis
• Budget tracking
• Savings insights
• Financial recommendations
"""

    print("✅ Assistant Ready\n")
    print(response)

except Exception as e:

    print("❌ Connection failed")
    print(f"Error: {e}")

    print("\n🛠 Running in offline mode.")
# Out:
# 🔄 Connecting to AI...
#
# 🤖 Thinking really hard with 'llama3.2'...
# [WARNING] Error during request (attempt 1): Connection error.
# WARNING:hands_on_ai:Error during request (attempt 1): Connection error.
# Oops! I got a little tangled up... Let's try that again 😊
# [WARNING] Error during request (attempt 2): Connection error.
# WARNING:hands_on_ai:Error during request (attempt 2): Connection error.
# ⚠️ AI unavailable — switching to offline mode.
#
# ✅ Assistant Ready
#
#
# 💡 Smart Finance Assistant
#
# • Spending analysis
# • Budget tracking
# • Savings insights
# • Financial recommendations

# %%
get_ipython().system('pip install hands-on-ai')
# Out:
# Requirement already satisfied: hands-on-ai in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (2.32.4)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (0.24.2)
# Requirement already satisfied: python-fasthtml in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (0.12.50)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (1.2.0)
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (1.27.2.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (2.0.2)
# Requirement already satisfied: instructor>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (1.15.1)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (2.12.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (3.13.5)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (0.18.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (3.1.6)
# Requirement already satisfied: jiter<0.14,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (0.13.0)
# Requirement already satisfied: openai<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (2.32.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (2.41.4)
# Requirement already satisfied: rich<15.0.0,>=13.7.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (13.9.4)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (9.1.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->hands-on-ai) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->hands-on-ai) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->hands-on-ai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->hands-on-ai) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->hands-on-ai) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->hands-on-ai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->hands-on-ai) (2026.4.22)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->hands-on-ai) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->hands-on-ai) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->hands-on-ai) (0.0.4)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx->hands-on-ai) (6.1.0)
# Requirement already satisfied: fastcore>=1.12.16 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (1.12.42)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (2.9.0.post0)
# Requirement already satisfied: starlette>0.33 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (0.52.1)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (3.3.1)
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (2.2.0)
# Requirement already satisfied: uvicorn>=0.30 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (0.46.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (0.28.1)
# Requirement already satisfied: fastlite>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (0.2.4)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (0.0.26)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (4.13.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->hands-on-ai) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->hands-on-ai) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->hands-on-ai) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (1.23.0)
# Requirement already satisfied: apswutils>=0.1.2 in /usr/local/lib/python3.12/dist-packages (from fastlite>=0.1.1->python-fasthtml->hands-on-ai) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.11.0->hands-on-ai) (3.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (4.67.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->python-fasthtml->hands-on-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->python-fasthtml->hands-on-ai) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0.0,>=13.7.0->instructor>=1.11.0->hands-on-ai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0.0,>=13.7.0->instructor>=1.11.0->hands-on-ai) (2.20.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (1.2.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (6.0.3)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->python-fasthtml->hands-on-ai) (2.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->python-fasthtml->hands-on-ai) (1.17.0)
# Requirement already satisfied: apsw in /usr/local/lib/python3.12/dist-packages (from apswutils>=0.1.2->fastlite>=0.1.1->python-fasthtml->hands-on-ai) (3.53.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.7.0->instructor>=1.11.0->hands-on-ai) (0.1.2)

# %% [raw]
# ---

# %% [markdown]
# # 🏗️ Foundation: Data Processing Skills
#
# Before building advanced features, establish solid data processing foundations. This section focuses on CSV transaction analysis - the core of your finance assistant.
#
# ## Foundation Skill Checkpoint ✅
#
# **Master these basics before advancing to chat/RAG/tools:**
# - [ ] Load and clean CSV transaction data
# - [ ] Handle real-world data issues (dollar signs, missing values)
# - [ ] Calculate spending summaries by category
# - [ ] Generate business-appropriate insights
# - [ ] Format output for professional presentation
# - [ ] Test functions with various data scenarios
#
# ::: {.callout-tip}
# ## 🤖 AI Collaboration Strategy
#
# For this foundation work, use AI to:
# 1. **Generate initial code** with specific business context
# 2. **Handle data cleaning** and validation
# 3. **Create professional formatting** for outputs
# 4. **Suggest business insights** from data patterns
# 5. **Help with testing** edge cases and error handling
#
# **Remember**: You're directing AI like a junior developer - always review and improve their suggestions!
# :::
#
# ## Sample Transaction Data Setup
#
# Create or load sample transaction data to work with:

# %%
# 🤖 AI Collaboration Opportunity:
# Ask AI to help you create realistic sample transaction data
# Include Australian businesses and various spending categories

# Sample data structure for testing
sample_transactions = {
    'Date': ['2024-08-01', '2024-08-02', '2024-08-03', '2024-08-04', '2024-08-05'],
    'Amount': ['$45.50', '$12.00', '$89.95', '$3.50', '-$25.00'],  # Note: includes $ signs and refund
    'Category': ['Groceries', 'Transport', 'Entertainment', 'Coffee', 'Refund'],
    'Description': ['Woolworths', 'Opal Card', 'Concert Tickets', 'Campus Cafe', 'Returned Item']
}

# Create DataFrame from sample data
df_sample = pd.DataFrame(sample_transactions)
print("📋 Sample transaction data created:")
print(df_sample)
# Out:
# 📋 Sample transaction data created:
#          Date   Amount       Category      Description
# 0  2024-08-01   $45.50      Groceries       Woolworths
# 1  2024-08-02   $12.00      Transport        Opal Card
# 2  2024-08-03   $89.95  Entertainment  Concert Tickets
# 3  2024-08-04    $3.50         Coffee      Campus Cafe
# 4  2024-08-05  -$25.00         Refund    Returned Item

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ---
#
# # 📊 Six-Step Development Methodology
#
# Your notebook must demonstrate the six-step methodology with clear evidence of AI collaboration at each step.
#
# ## STEP 1: Understand the Problem
#
# **🎯 Define Your Finance Problem**
#
# In this section, clearly state your chosen finance problem in business terms.
#
# ::: {.callout-note}
# ## Problem Definition Template
#
# *Example: "I want to help people understand their spending habits by analyzing their bank transaction exports. The system should identify spending patterns, highlight potential savings opportunities, and provide actionable financial insights in easy-to-understand language."*
#
# **🤖 AI Prompt to Try:**
# ```
# "Help me brainstorm specific personal finance problems that could be solved
# with a CSV analysis tool. I'm interested in helping people with budgeting
# and spending awareness. What are common financial challenges that data
# analysis could address?"
# ```
#
# **Your Problem Statement:**
# [Write your specific finance problem here - be clear about who you're helping and what value you're providing]
# Problem statement: I want to help university students manage their monthly budgets by analyzing their bank transaction CSV files. The system should identify categories where users overspend, compare spending against budget limits, and provide simple recommendations to improve financial control.
#
# ## STEP 2: Identify Inputs and Outputs
#
# **📥 Define Your Data Flow**
#
# Clearly specify what data you'll work with and what insights you'll generate.
#
# ## Input/Output Analysis Template
#
# **Inputs:**
# - CSV file with transaction data (columns: Date, Amount, Category, Description)
# - User preferences (spending goals, categories to focus on)
# - Time period for analysis
#
# **Outputs:**
# - Total spending summary by category
# - Average spending patterns
# - Spending trend analysis
# - Actionable savings recommendations
# - Visual spending breakdown (future enhancement)
#
# **🤖 AI Prompt to Try:**
# ```
# "For a personal finance assistant that analyzes CSV transaction data,
# what are the most valuable inputs I should collect and outputs I should
# provide? Consider both technical data processing and business value
# for the user."
# ```
#
# **Your Input/Output Definition:**
# [Define your specific inputs and outputs here]
# ```text id="x4w4oj"
# **Inputs:**
#
# - CSV file containing bank transaction data
# (columns: Date, Amount, Category, Description)
#
# - Student budget limits for different spending categories
# (e.g., food, entertainment, transport)
#
# - Selected time period for analysis
# (weekly or monthly)
#
# **Outputs:*
#
# - Monthly spending summary by category
#
# - Overspending detection compared to budget limits
#
# - Average spending patterns and trends
#
# - Simple financial recommendations for improving budgeting habits
#
# - Identification of categories with the highest spending
#
# - Visual spending charts and budget comparison graphs
# (future enhancement)
# ```
#
#
# ## STEP 3: Work the Problem by Hand
#
# **✋ Manual Calculation Examples**
#
# Show 2-3 worked examples to understand the logic before coding.
#
#
# ## Example Business Calculation
#
# Given this sample data:
#
# | Date | Amount | Category | Description |
# |------|--------|----------|-------------|
# | 2024-08-01 | $45.50 | Groceries | Woolworths |
# | 2024-08-02 | $12.00 | Transport | Opal Card |
# | 2024-08-03 | $89.95 | Entertainment | Concert |
# | 2024-08-04 | -$15.00 | Refund | Returned item |
#
# **Manual Calculations:**
# - Total Spending: $45.50 + $12.00 + $89.95 - $15.00 = $132.45
# - By Category: Groceries $45.50, Transport $12.00, Entertainment $89.95
# - Average Transaction: $132.45 ÷ 4 = $33.11
# - Insight: Entertainment represents 67% of positive spending
#
# **🤖 AI Prompt to Try:**
# ```
# "Give me 3 realistic examples of Australian transaction data with different
# scenarios (normal spending, refunds, large purchases). Show me how to manually
# calculate meaningful financial insights from each scenario."
# ```
#
# **Your Manual Examples:**
# [Work through your own examples here - this helps you understand the business logic]
# Example 1: Normal Student Pending
# | Date       | Amount | Category      | Description  |
# | ---------- | ------ | ------------- | ------------ |
# | 2026-05-01 | $68.40 | Groceries     | Coles        |
# | 2026-05-02 | $14.50 | Transport     | Transperth   |
# | 2026-05-03 | $22.90 | Food          | McDonald's   |
# | 2026-05-04 | $35.00 | Entertainment | Hoyts Cinema |
# | 2026-05-05 | $9.80  | Coffee        | Starbucks    |
#
# **Manual Calculations:**
# - Total Spending: $68.40 + $14.50 + $22.90 + $35.00 + $9.80
# = $150.60
# - By Category: Groceries: $68.40,
# Transport: $14.50, Food: $22.90, Entertainment: $35.00, Coffee: $9.80
# - Average Transaction: $150.60 ÷ 5
# = $30.12
# - Insight: Groceries account for approximately 45% of total spending.
# Entertainment and takeaway food together total $57.90,
# which may indicate discretionary spending.
#
# Example 2: Refund Scenario
# | Date       | Amount  | Category  | Description    |
# | ---------- | ------- | --------- | -------------- |
# | 2026-05-06 | $120.00 | Shopping  | Kmart          |
# | 2026-05-07 | $18.50  | Transport | Uber           |
# | 2026-05-08 | -$45.00 | Refund    | Returned Shoes |
# | 2026-05-09 | $27.80  | Food      | Nando's        |
# | 2026-05-10 | $65.00  | Bills     | Internet       |
# **Manual Calculations:**
# - Total Spending: $120.00 + $18.50 - $45.00 + $27.80 + $65.00
# = $186.30
# - Positive Spending Only: $120.00 + $18.50 + $27.80 + $65.00
# = $231.30
# - Refund Value: Refund Total = -$45.00
# - Average Transaction: $186.30 ÷ 5
# = $37.26
# - Financial Insight: Shopping was the highest expense category at $120.00.
# The refund reduced total spending by approximately 19%.
# Bills and shopping represented most monthly expenses.
# Example 3: Large Purchase Scenario
# | Date       | Amount    | Category     | Description     |
# | ---------- | --------- | ------------ | --------------- |
# | 2026-05-11 | $72.30    | Groceries    | Woolworths      |
# | 2026-05-12 | $1,850.00 | Electronics  | JB Hi-Fi Laptop |
# | 2026-05-13 | $16.20    | Transport    | Transperth      |
# | 2026-05-14 | $31.50    | Food         | Grill'd         |
# | 2026-05-15 | $14.90    | Subscription | Spotify         |
# **Manual Calculations:**
# - Total Spending: $72.30 + $1,850.00 + $16.20 + $31.50 + $14.90
# = $1,984.90
# - Spending Without Large Purchase:$1,984.90 - $1,850.00
# = $134.90
# - Average Transaction: $1,984.90 ÷ 5
# = $396.98
# - Electronics Spending Percentage: ($1,850.00 ÷ $1,984.90) × 100
# ≈ 93%
# - Financial Insight: The laptop purchase heavily impacted monthly spending,
# representing approximately 93% of total expenses.
# Without the large purchase, normal living expenses remained relatively low.
# This transaction may need installment planning or savings allocation.
# ## STEP 4: Write Pseudocode
#
# **📝 Plan Your Solution Logic**
#
# Sketch the algorithm in plain English before coding.
#
#
# ## Pseudocode Template
#
# ```
# FUNCTION analyze_spending_data(csv_file):
#     // Step 1: Load and validate data
#     - Read CSV file into DataFrame
#     - Check for required columns (Date, Amount, Category, Description)
#     - Handle missing or invalid data
#
#     // Step 2: Clean financial data
#     - Remove dollar signs from Amount column
#     - Convert to numeric values
#     - Separate positive spending from refunds
#
#     // Step 3: Calculate business metrics
#     - Group transactions by category
#     - Calculate totals, averages, counts per category
#     - Identify spending patterns and outliers
#
#     // Step 4: Generate insights
#     - Calculate percentages of total spending
#     - Identify top spending categories
#     - Suggest potential savings opportunities
#
#     // Step 5: Format for presentation
#     - Create business-friendly output
#     - Include currency formatting
#     - Add explanatory text for insights
#
#     RETURN formatted_analysis
# ```
#
# **🤖 AI Prompt to Try:**
# ```
# "Review my pseudocode for analyzing spending data from a CSV. Are there any
# edge cases I'm missing? What business logic should I add to make this more
# valuable for personal finance insights?"
# ```
#
#
# **Your Pseudocode:**
# [Write your detailed algorithm here]
# 1. data validation,
# 2. financial data cleaning,
# 3. business metric calculation,
# 4. insight generation,
# 5. presentation formatting.
#
# Missing Edge Cases:
#
# 1. Empty CSV File
# - The system should check whether the uploaded CSV file is empty before processing.
#
# 2. Missing Required Columns
# - Some transaction exports may not contain all required columns.
# - The algorithm should validate that Date, Amount, Category, and Description exist.
#
# 3. Invalid Financial Data
# - Amount values may contain:
#     "$1,200.50"
#     commas,
#     text,
#     blank values.
# - The system should safely clean and convert these values into numeric format.
#
# 4. Duplicate Transactions
# - Duplicate bank transactions may distort spending calculations.
# - The system should detect and remove duplicate rows.
#
# 5. Invalid or Inconsistent Date Formats
# - Different banks may use different date formats.
# - Dates should be standardized before analysis.
#
# 6. Refund Transactions
# - Negative values should be separated from normal spending
#   because refunds affect totals and averages differently.
#
# 7. Zero-Value Transactions
# - Transactions with $0 values may incorrectly affect averages and statistics.
#
# Additional Business Logic Suggestions:
#
# 1. Budget Comparison
# - Compare spending against user-defined category budgets.
# - Example insight:
#   "Food spending exceeded budget by $45."
#
# 2. Subscription Detection
# - Detect recurring transactions such as Spotify or Netflix subscriptions.
#
# 3. Spending Trend Analysis
# - Compare spending across weeks or months to identify increases or decreases.
#
# 4. Large Purchase Detection
# - Identify unusually large purchases that heavily impact monthly spending.
#
# 5. Savings Estimation
# - Calculate estimated savings using:
#   Savings = Income - Expenses
#
# 6. Discretionary Spending Analysis
# - Identify non-essential spending categories such as entertainment,
#   takeaway food, or shopping.
#
# 7. Personalized Financial Insights
# - Generate simple recommendations based on spending behavior.
# - Example:
#   "Reducing takeaway spending by 15% could improve monthly savings."
# ## STEP 5: Convert to Python
#
# **💻 Implementation with AI Collaboration**
#
# Now implement your solution using AI assistance. Focus on creating professional, business-appropriate code.
#
#
# ## 🤖 Implementation Strategy
#
# **Effective AI Prompts for Implementation:**
# ```
# "I'm implementing a Smart Finance Assistant. Based on my pseudocode, please create
# a Python function that [specific functionality]. The code should:
# - Handle real-world CSV data issues (dollar signs, missing values)
# - Include clear comments explaining business logic
# - Use professional variable names
# - Format output for business presentation
# - Include basic error handling"
# ```
#
# **Remember to critique and improve AI responses before using them!**
# :::
#
# ### Foundation Data Processing Functions

# %%
import pandas as pd

# Smart Finance Assistant
# Data Loading and Cleaning Utility

def load_and_clean_transaction_data(csv_file):
    """
    Loads transaction data from a CSV file, cleans the 'Amount' column,
    and ensures required columns are present.

    Args:
        csv_file (str): Path to the CSV file.

    Returns:
        pandas.DataFrame: Cleaned transaction DataFrame.

    Raises:
        ValueError: If a required column is missing.
        Exception: For other file processing errors.
    """
    try:
        # Load CSV file
        transactions = pd.read_csv(csv_file)

        # Check required columns
        required_columns = [
            "Date",
            "Amount",
            "Category",
            "Description"
        ]

        for column in required_columns:
            if column not in transactions.columns:
                raise ValueError(f"Missing required column: {column}")

        # Clean Amount column
        transactions["Amount"] = (
            transactions["Amount"]
            .astype(str)
            .str.replace("$", "", regex=False)
            .str.replace(",", "", regex=False)
        )

        # Convert to numeric
        transactions["Amount"] = pd.to_numeric(
            transactions["Amount"],
            errors="coerce"
        )

        # Remove rows where 'Amount' couldn't be converted to a number
        transactions = transactions.dropna(
            subset=["Amount"]
        )

        return transactions

    except ValueError as e:
        print(f"❌ Data validation error: {e}")
        raise # Re-raise to stop execution or handle higher up
    except FileNotFoundError:
        print(f"❌ Error: CSV file not found at {csv_file}")
        raise
    except Exception as e:
        print(f"❌ An unexpected error occurred during data loading/cleaning: {e}")
        raise

# The previous analyze_spending_data function (if it existed here)
# has been refactored. The `load_and_clean_transaction_data` function
# now handles the initial data preparation, which is then used by
# `analyze_spending_patterns` (defined in cell _K8KDSqg6WsK)
# and `generate_financial_recommendations`.

# %%
import pandas as pd

# Sample data structure for testing
sample_transactions = {
    'Date': ['2024-08-01', '2024-08-02', '2024-08-03', '2024-08-04', '2024-08-05'],
    'Amount': ['$45.50', '$12.00', '$89.95', '$3.50', '-$25.00'],  # Note: includes $ signs and refund
    'Category': ['Groceries', 'Transport', 'Entertainment', 'Coffee', 'Refund'],
    'Description': ['Woolworths', 'Opal Card', 'Concert Tickets', 'Campus Cafe', 'Returned Item']
}

# Create DataFrame from sample data
df_sample = pd.DataFrame(sample_transactions)

df_sample.to_csv("sample_transactions (1).csv", index=False)
clean_data = load_and_clean_transaction_data(
    "sample_transactions (1).csv"
)

print(clean_data.head())
# Out:
#          Date  Amount       Category      Description
# 0  2024-08-01   45.50      Groceries       Woolworths
# 1  2024-08-02   12.00      Transport        Opal Card
# 2  2024-08-03   89.95  Entertainment  Concert Tickets
# 3  2024-08-04    3.50         Coffee      Campus Cafe
# 4  2024-08-05  -25.00         Refund    Returned Item

# %%
# 🤖 AI Collaboration: Spending Analysis Function

def analyze_spending_patterns(df):
    """
    Analyze spending patterns and generate business insights.

    Args:
        df (pandas.DataFrame):
            Cleaned transaction DataFrame

    Returns:
        dict:
            Analysis results and business insights
    """

    try:
        # Calculate total spending
        total_spending = df["Amount"].sum()

        # Spending by category
        category_totals = (
            df.groupby("Category")["Amount"]
            .sum()
            .sort_values(ascending=False)
        )

        # Percentage by category
        category_percentages = (
            (category_totals / total_spending) * 100
        ).round(2)

        # Average transaction
        average_transaction = df["Amount"].mean()

        # Highest spending category
        top_category = category_totals.idxmax()

        # Highest spending amount
        top_category_amount = category_totals.max()

        # Generate business insights
        insights = []

        insights.append(
            f"Total spending is ${total_spending:.2f}."
        )

        insights.append(
            f"The highest spending category is "
            f"{top_category} "
            f"with ${top_category_amount:.2f} spent."
        )

        insights.append(
            f"The average transaction amount is "
            f"${average_transaction:.2f}."
        )

        # Savings recommendation
        if category_percentages.iloc[0] > 40:
            insights.append(
                f"{top_category} represents more than 40% "
                f"of total spending. Consider reviewing "
                f"expenses in this category."
            )

        # Build results dictionary
        analysis_results = {
            "total_spending": total_spending,
            "average_transaction": average_transaction,
            "category_totals": category_totals,
            "category_percentages": category_percentages,
            "top_category": top_category,
            "business_insights": insights
        }

        # Display formatted summary
        print("✅ Spending Analysis Completed!\n")

        print(f"💰 Total Spending: ${total_spending:.2f}")
        print(
            f"📊 Average Transaction: "
            f"${average_transaction:.2f}"
        )
        print(f"🏆 Top Category: {top_category}")

        print("\n📂 Spending by Category:")
        print(category_totals)

        print("\n📈 Category Percentages:")
        print(category_percentages)

        print("\n💡 Business Insights:")
        for insight in insights:
            print(f"- {insight}")

        return analysis_results

    except Exception as e:
        print(f"❌ Error analyzing spending patterns: {e}")

# %%
analysis = analyze_spending_patterns(clean_data)
# Out:
# ✅ Spending Analysis Completed!
#
# 💰 Total Spending: $125.95
# 📊 Average Transaction: $25.19
# 🏆 Top Category: Entertainment
#
# 📂 Spending by Category:
# Category
# Entertainment    89.95
# Groceries        45.50
# Transport        12.00
# Coffee            3.50
# Refund          -25.00
# Name: Amount, dtype: float64
#
# 📈 Category Percentages:
# Category
# Entertainment    71.42
# Groceries        36.13
# Transport         9.53
# Coffee            2.78
# Refund          -19.85
# Name: Amount, dtype: float64
#
# 💡 Business Insights:
# - Total spending is $125.95.
# - The highest spending category is Entertainment with $89.95 spent.
# - The average transaction amount is $25.19.
# - Entertainment represents more than 40% of total spending. Consider reviewing expenses in this category.

# %%
# 🤖 AI Collaboration: Business Insights Generator

def generate_financial_recommendations(analysis_data):
    """
    Generate actionable financial recommendations
    based on spending analysis.

    Args:
        analysis_data (dict):
            Dictionary containing spending analysis results

    Returns:
        str:
            Formatted recommendation report
    """

    try:
        # Extract analysis data
        total_spending = analysis_data["total_spending"]
        average_transaction = analysis_data["average_transaction"]
        top_category = analysis_data["top_category"]
        category_percentages = analysis_data["category_percentages"]

        # Create recommendation list
        recommendations = []

        recommendations.append(
            "SMART FINANCE ASSISTANT REPORT"
        )

        recommendations.append("=" * 40)

        recommendations.append(
            f"Total Spending: ${total_spending:.2f}"
        )

        recommendations.append(
            f"Average Transaction Amount: "
            f"${average_transaction:.2f}"
        )

        recommendations.append(
            f"Top Spending Category: {top_category}"
        )

        recommendations.append("\nFINANCIAL INSIGHTS")

        # Analyze category percentages
        for category, percentage in category_percentages.items():

            recommendations.append(
                f"- {category}: {percentage:.2f}% "
                f"of total spending"
            )

            # Business recommendations
            if percentage > 40:
                recommendations.append(
                    f"  Recommendation: Spending in "
                    f"{category} is very high. "
                    f"Consider setting a monthly budget "
                    f"limit for this category."
                )

            elif percentage > 25:
                recommendations.append(
                    f"  Recommendation: Monitor spending "
                    f"in {category} to maintain a balanced "
                    f"financial plan."
                )

        # Savings suggestions
        recommendations.append("\nSAVINGS OPPORTUNITIES")

        if average_transaction > 100:
            recommendations.append(
                "- Large average transaction amounts "
                "may indicate opportunities to reduce "
                "non-essential purchases."
            )

        recommendations.append(
            "- Track recurring expenses monthly."
        )

        recommendations.append(
            "- Consider setting category spending goals."
        )

        recommendations.append(
            "- Review subscriptions and unnecessary expenses."
        )

        recommendations.append(
            "- Build an emergency savings fund "
            "for financial stability."
        )

        # Final summary
        recommendations.append("\nFINAL SUMMARY")

        recommendations.append(
            "Your spending analysis has been completed "
            "successfully. Regular monitoring of spending "
            "patterns can improve budgeting decisions "
            "and long-term financial health."
        )

        # Convert list to formatted string
        final_report = "\n".join(recommendations)

        return final_report

    except Exception as e:
        return f"❌ Error generating recommendations: {e}"

# %%
analysis = analyze_spending_patterns(clean_data)
recommendations = generate_financial_recommendations(
    analysis
)

print(recommendations)
# Out:
# ✅ Spending Analysis Completed!
#
# 💰 Total Spending: $125.95
# 📊 Average Transaction: $25.19
# 🏆 Top Category: Entertainment
#
# 📂 Spending by Category:
# Category
# Entertainment    89.95
# Groceries        45.50
# Transport        12.00
# Coffee            3.50
# Refund          -25.00
# Name: Amount, dtype: float64
#
# 📈 Category Percentages:
# Category
# Entertainment    71.42
# Groceries        36.13
# Transport         9.53
# Coffee            2.78
# Refund          -19.85
# Name: Amount, dtype: float64
#
# 💡 Business Insights:
# - Total spending is $125.95.
# - The highest spending category is Entertainment with $89.95 spent.
# - The average transaction amount is $25.19.
# - Entertainment represents more than 40% of total spending. Consider reviewing expenses in this category.
# SMART FINANCE ASSISTANT REPORT
# ========================================
# Total Spending: $125.95
# Average Transaction Amount: $25.19
# Top Spending Category: Entertainment
#
# FINANCIAL INSIGHTS
# - Entertainment: 71.42% of total spending
#   Recommendation: Spending in Entertainment is very high. Consider setting a monthly budget limit for this category.
# - Groceries: 36.13% of total spending
#   Recommendation: Monitor spending in Groceries to maintain a balanced financial plan.
# - Transport: 9.53% of total spending
# - Coffee: 2.78% of total spending
# - Refund: -19.85% of total spending
#
# SAVINGS OPPORTUNITIES
# - Track recurring expenses monthly.
# - Consider setting category spending goals.
# - Review subscriptions and unnecessary expenses.
# - Build an emergency savings fund for financial stability.
#
# FINAL SUMMARY
# Your spending analysis has been completed successfully. Regular monitoring of spending patterns can improve budgeting decisions and long-term financial health.

# %% [markdown]
# ---
#
# # 🌐 Advanced Features: Integrating AI Components
#
# Once your foundation data processing is solid, integrate advanced AI features using hands-on-ai.
#
# ## Chat Interface Integration

# %%
# !pip install hands-on-ai

# 🤖 AI Collaboration: Financial Advice Chatbot with Real Data
from hands_on_ai import chat

def create_finance_chat_personality():
    """
    Set up a financial advisor chat personality with access to user's spending data
    """

    # Your actual spending data
    spending_data = """
SPENDING ANALYSIS SUMMARY

Total Spending: $125.95
Average Transaction: $25.19

Category Breakdown:
- Entertainment: $89.95 (71.42%)
- Groceries: $45.50 (36.13%)
- Transport: $12.00 (9.53%)
- Coffee: $3.50 (2.78%)

Refund Activity:
- Total Refund Value: $25.00

Financial Insights:
1. Entertainment is the highest spending category.
2. Coffee spending is relatively low.
3. Limited transaction history available.
4. Spending percentages may overlap due to refunds.
    """
    # The system prompt is returned to be prepended to user questions
    return system_prompt
# Out:
# Requirement already satisfied: hands-on-ai in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (2.32.4)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (0.24.2)
# Requirement already satisfied: python-fasthtml in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (0.12.50)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (1.2.0)
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (1.27.2.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (2.0.2)
# Requirement already satisfied: instructor>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (1.15.1)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from hands-on-ai) (2.12.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (3.13.5)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (0.18.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (3.1.6)
# Requirement already satisfied: jiter<0.14,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (0.13.0)
# Requirement already satisfied: openai<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (2.32.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (2.41.4)
# Requirement already satisfied: rich<15.0.0,>=13.7.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (13.9.4)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.11.0->hands-on-ai) (9.1.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->hands-on-ai) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->hands-on-ai) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->hands-on-ai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->hands-on-ai) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->hands-on-ai) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->hands-on-ai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->hands-on-ai) (2026.4.22)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->hands-on-ai) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->hands-on-ai) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->hands-on-ai) (0.0.4)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx->hands-on-ai) (6.1.0)
# Requirement already satisfied: fastcore>=1.12.16 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (1.12.42)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (2.9.0.post0)
# Requirement already satisfied: starlette>0.33 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (0.52.1)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (3.3.1)
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (2.2.0)
# Requirement already satisfied: uvicorn>=0.30 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (0.46.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (0.28.1)
# Requirement already satisfied: fastlite>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (0.2.4)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (0.0.26)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml->hands-on-ai) (4.13.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->hands-on-ai) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->hands-on-ai) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->hands-on-ai) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (1.23.0)
# Requirement already satisfied: apswutils>=0.1.2 in /usr/local/lib/python3.12/dist-packages (from fastlite>=0.1.1->python-fasthtml->hands-on-ai) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.11.0->hands-on-ai) (3.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (4.67.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->python-fasthtml->hands-on-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->python-fasthtml->hands-on-ai) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0.0,>=13.7.0->instructor>=1.11.0->hands-on-ai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0.0,>=13.7.0->instructor>=1.11.0->hands-on-ai) (2.20.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (1.2.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (6.0.3)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->python-fasthtml->hands-on-ai) (2.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->python-fasthtml->hands-on-ai) (1.17.0)
# Requirement already satisfied: apsw in /usr/local/lib/python3.12/dist-packages (from apswutils>=0.1.2->fastlite>=0.1.1->python-fasthtml->hands-on-ai) (3.53.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.7.0->instructor>=1.11.0->hands-on-ai) (0.1.2)

# %% [markdown]
# ## RAG System for Financial Documents

# %%
# ==================================================
# SMART FINANCE ASSISTANT
# CSV Analysis + AI Financial Advice
# ==================================================

try:
    import hands_on_ai
except:
    # !pip install hands-on-ai -q

import pandas as pd
from hands_on_ai import rag
from hands_on_ai.chat import get_response # Import get_response function directly

# --------------------------------------------------
# STEP 1: Analyze Spending Data
# --------------------------------------------------

def analyze_spending_data(csv_file):

    try:
        # Load CSV file
        data = pd.read_csv(csv_file)

        # Required columns
        required_columns = [
            "Date",
            "Amount",
            "Category",
            "Description"
        ]

        # Validate columns
        for column in required_columns:

            if column not in data.columns:

                return {
                    "error":
                    f"Missing column: {column}"
                }

        # Clean Amount column
        data["Amount"] = (
            data["Amount"]
            .astype(str)
            .str.replace("$", "", regex=False)
            .str.replace(",", "", regex=False)
        )

        # Convert to numbers
        data["Amount"] = pd.to_numeric(
            data["Amount"],
            errors="coerce"
        )

        # Remove invalid rows
        data = data.dropna(subset=["Amount"])

        # Separate spending & refunds
        spending = data[data["Amount"] > 0]
        refunds = data[data["Amount"] < 0]

        # Business calculations
        total_spending = spending["Amount"].sum()

        average_transaction = (
            spending["Amount"].mean()
        )

        category_totals = (
            spending.groupby("Category")["Amount"]
            .sum()
            .sort_values(ascending=False)
        )

        top_category = category_totals.idxmax()

        # Create category summary
        category_summary = []

        for category, amount in category_totals.items():

            percentage = (
                amount / total_spending
            ) * 100

            category_summary.append(
                f"- {category}: "
                f"${amount:,.2f} "
                f"({percentage:.1f}%)"
            )

        # Generate financial report
        financial_report = f"""
SMART FINANCE REPORT
====================

Total Spending: ${total_spending:,.2f}
Average Transaction: ${average_transaction:,.2f}

Top Spending Category:
- {top_category}

CATEGORY BREAKDOWN:
{chr(10).join(category_summary)}

Refund Value:
${abs(refunds['Amount'].sum()):,.2f}

FINANCIAL INSIGHT:
Regular spending analysis can improve
budgeting awareness and savings habits.
"""

        return financial_report

    except Exception as error:

        return f"Error: {error}"

# --------------------------------------------------
# STEP 2: Prepare RAG Documents
# --------------------------------------------------

def prepare_rag_documents(report):

    return [

        {
            "title": "User Spending Report",
            "content": report
        },

        {
            "title": "Budgeting Advice",
            "content": """
The 50/30/20 rule suggests:
- 50% for needs
- 30% for wants
- 20% for savings

Entertainment spending should remain
within the wants category.
"""
        },

        {
            "title": "Savings Strategies",
            "content": """
Ways to improve savings:
- Reduce unnecessary subscriptions
- Set monthly category budgets
- Track entertainment spending
- Build an emergency fund
"""
        }
    ]

# --------------------------------------------------
# STEP 3: AI Financial Assistant
# --------------------------------------------------

report = analyze_spending_data(
    "sample_transactions (1).csv" # Changed filename here
)

print(report)

rag_documents = prepare_rag_documents(
    report
)

question = (
    "How can I reduce entertainment spending?"
)

# Construct a system prompt using rag_documents content
rag_context = "\n".join([f"## {doc['title']}\n{doc['content']}" for doc in rag_documents])
system_prompt_with_context = f"""
You are a Smart Finance Assistant. Your responses should be based on the following financial information:

{rag_context}

Please provide advice based on the user's question and the context provided.
"""

# Combine the system prompt and the question into a single prompt for get_response
combined_prompt = f"{system_prompt_with_context}\n\nUser question: {question}"

response = get_response(
    combined_prompt
)

print("\n🤖 AI FINANCIAL ADVICE")
print(response)
# Out:
# SMART FINANCE REPORT
# ====================
#
# Total Spending: $150.95
# Average Transaction: $37.74
#
# Top Spending Category:
# - Entertainment
#
# CATEGORY BREAKDOWN:
# - Entertainment: $89.95 (59.6%)
# - Groceries: $45.50 (30.1%)
# - Transport: $12.00 (7.9%)
# - Coffee: $3.50 (2.3%)
#
# Refund Value:
# $25.00
#
# FINANCIAL INSIGHT:
# Regular spending analysis can improve
# budgeting awareness and savings habits.
# [WARNING] Error during request (attempt 1): Connection error.
# WARNING:hands_on_ai:Error during request (attempt 1): Connection error.
# Oops! I got a little tangled up... Let's try that again 😊
# [WARNING] Error during request (attempt 2): Connection error.
# WARNING:hands_on_ai:Error during request (attempt 2): Connection error.
# 🤖 AI FINANCIAL ADVICE
# ❌ Error: Connection error.

# %% [markdown]
# ## Custom Financial Tools

# %%
# 🤖 AI Collaboration: Custom Tool Development

from hands_on_ai import agent
import math

def create_savings_calculator_tool(
    current_savings,
    monthly_contribution,
    target_amount
):
    """
    Calculate time required to reach a savings goal.

    Args:
        current_savings (float):
            Current amount saved

        monthly_contribution (float):
            Monthly savings contribution

        target_amount (float):
            Savings goal target

    Returns:
        str:
            Formatted savings analysis
    """

    try:
        # Input validation
        if current_savings < 0:
            return "❌ Current savings cannot be negative."

        if monthly_contribution <= 0:
            return (
                "❌ Monthly contribution must be greater than zero."
            )

        if target_amount <= 0:
            return "❌ Target amount must be greater than zero."

        if current_savings >= target_amount:
            return (
                "✅ You have already reached your savings goal!"
            )

        # Calculate remaining amount
        remaining_amount = (
            target_amount - current_savings
        )

        # Calculate months required
        months_required = math.ceil(
            remaining_amount / monthly_contribution
        )

        # Convert months to years/months
        years = months_required // 12
        months = months_required % 12

        # Build formatted report
        report = []

        report.append(
            "💰 SAVINGS GOAL CALCULATOR"
        )

        report.append("=" * 35)

        report.append(
            f"Current Savings: "
            f"${current_savings:,.2f}"
        )

        report.append(
            f"Monthly Contribution: "
            f"${monthly_contribution:,.2f}"
        )

        report.append(
            f"Target Savings Goal: "
            f"${target_amount:,.2f}"
        )

        report.append(
            f"Remaining Amount: "
            f"${remaining_amount:,.2f}"
        )

        report.append(
            f"\nEstimated Time to Reach Goal:"
        )

        report.append(
            f"{months_required} months"
        )

        # Add year/month breakdown
        if years > 0:
            report.append(
                f"Approximately {years} year(s) "
                f"and {months} month(s)"
            )

        # Financial advice
        report.append("\n📈 FINANCIAL ADVICE")

        if months_required > 60:
            report.append(
                "- Consider increasing monthly contributions "
                "to reach your goal faster."
            )

        elif months_required < 12:
            report.append(
                "- Excellent progress! Your goal is achievable "
                "within one year."
            )

        else:
            report.append(
                "- Stay consistent with your monthly savings habit."
            )

        report.append(
            "- Review spending patterns regularly "
            "to identify extra savings opportunities."
        )

        # Return formatted string
        return "\n".join(report)

    except Exception as e:
        return f"❌ Error calculating savings goal: {e}"


# Register tool with agent system
agent.register_tool(
    "savings_calculator",
    "A calculator that determines the time required to reach a savings goal. Requires `current_savings` (float), `monthly_contribution` (float), and `target_amount` (float). Returns a formatted string with estimated time and financial advice.",
    create_savings_calculator_tool
)

# %%
result = create_savings_calculator_tool(
    current_savings=2000,
    monthly_contribution=500,
    target_amount=10000
)

print(result)
# Out:
# 💰 SAVINGS GOAL CALCULATOR
# ===================================
# Current Savings: $2,000.00
# Monthly Contribution: $500.00
# Target Savings Goal: $10,000.00
# Remaining Amount: $8,000.00
#
# Estimated Time to Reach Goal:
# 16 months
# Approximately 1 year(s) and 4 month(s)
#
# 📈 FINANCIAL ADVICE
# - Stay consistent with your monthly savings habit.
# - Review spending patterns regularly to identify extra savings opportunities.

# %% [markdown]
# ## Gradio UI Integration

# %%
# 🤖 AI Collaboration: Professional UI Design

import gradio as gr
import pandas as pd


def create_finance_assistant_ui():

    # CSV Analysis Function
    def process_finance_file(file):

        try:
            # Load and clean data
            clean_data = load_and_clean_transaction_data(
                file.name
            )

            # Analyze spending
            analysis = analyze_spending_patterns(
                clean_data
            )

            # Generate recommendations
            recommendations = (
                generate_financial_recommendations(
                    analysis
                )
            )

            return recommendations

        except Exception as e:
            return f"❌ Error processing file: {e}"

    # Savings Calculator Wrapper
    def calculate_savings(
        current_savings,
        monthly_contribution,
        target_amount
    ):

        return create_savings_calculator_tool(
            current_savings,
            monthly_contribution,
            target_amount
        )

    # Chatbot Function
    def finance_chat(user_message):

        try:
            finance_personality = (
                create_finance_chat_personality()
            )

            response = chat.say(
                user_message,
                system_prompt=finance_personality
            )

            return response

        except Exception:

            # Fallback response
            return (
                "I recommend reviewing your monthly "
                "spending habits, reducing unnecessary "
                "expenses, and setting clear savings goals."
            )

    # Main Gradio Interface
    with gr.Blocks(
        title="Smart Finance Assistant"
    ) as demo:

        gr.Markdown(
            """
            # 💰 Smart Finance Assistant

            Analyze spending habits, generate financial
            insights, chat with an AI finance assistant,
            and calculate savings goals.
            """
        )

        # TAB 1 — Spending Analysis
        with gr.Tab("📊 Spending Analysis"):

            file_input = gr.File(
                label="Upload Transaction CSV File"
            )

            analysis_output = gr.Textbox(
                label="Financial Analysis Report",
                lines=25
            )

            analyze_button = gr.Button(
                "Analyze Spending"
            )

            analyze_button.click(
                fn=process_finance_file,
                inputs=file_input,
                outputs=analysis_output
            )

        # TAB 2 — Finance Chatbot
        with gr.Tab("🤖 Finance Chatbot"):

            chatbot_input = gr.Textbox(
                label="Ask a Financial Question",
                placeholder=(
                    "Example: How can I reduce "
                    "my food expenses?"
                )
            )

            chatbot_output = gr.Textbox(
                label="AI Financial Advice",
                lines=10
            )

            chat_button = gr.Button(
                "Get Advice"
            )

            chat_button.click(
                fn=finance_chat,
                inputs=chatbot_input,
                outputs=chatbot_output
            )

        # TAB 3 — Savings Calculator
        with gr.Tab("💰 Savings Calculator"):

            current_savings = gr.Number(
                label="Current Savings",
                value=0
            )

            monthly_contribution = gr.Number(
                label="Monthly Contribution",
                value=100
            )

            target_amount = gr.Number(
                label="Target Savings Goal",
                value=1000
            )

            savings_output = gr.Textbox(
                label="Savings Goal Report",
                lines=15
            )

            calculate_button = gr.Button(
                "Calculate Savings Goal"
            )

            calculate_button.click(
                fn=calculate_savings,
                inputs=[
                    current_savings,
                    monthly_contribution,
                    target_amount
                ],
                outputs=savings_output
            )

        # Footer
        gr.Markdown(
            """
            ---
            Smart Finance Assistant
            AI-Powered Personal Finance Analysis Tool
            """
        )

    return demo


# Launch application
demo = create_finance_assistant_ui()
demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://e5e4eea378db156f55.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e5e4eea378db156f55.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ---
#
# # 🧪 STEP 6: Test with a Variety of Data
#
# **🔍 Comprehensive Testing Strategy**
#
# Create thorough tests for your Smart Finance Assistant to ensure it handles real-world scenarios.
#
# ::: {.callout-tip}
# ## 🤖 AI Collaboration for Testing
#
# **Effective Testing Prompts:**
# ```
# "Help me create comprehensive test cases for my finance assistant. Include:
# - Normal transaction data
# - Edge cases (refunds, large amounts, missing data)
# - Invalid data scenarios (corrupted files, wrong formats)
# - Business logic validation (spending calculations, recommendations)
# Create assert statements to verify each scenario."
# ```
# :::
#
# ## Foundation Function Tests

# %%
# 🤖 AI Collaboration: Comprehensive Test Suite
# Ask AI to help you create thorough test cases

def create_test_datasets():
    """
    Create various test datasets for comprehensive testing

    🤖 AI Collaboration Prompt:
    "Create realistic test datasets for a finance assistant including:
    1. Normal spending data with various categories
    2. Edge cases: refunds (negative amounts), missing data, zero amounts
    3. Data quality issues: invalid formats, extreme values
    4. Business scenarios: high spending months, savings patterns
    Include Australian business names and realistic amounts."
    """
    # Your AI-generated test data goes here
    pass

def test_data_loading_function():
    """
    Test the data loading and cleaning functionality

    🤖 AI Collaboration Prompt:
    "Create assert statements to test my data loading function with:
    - Valid CSV data
    - CSV with dollar signs in amounts
    - Missing values and invalid data
    - Empty files and corrupted data
    Verify that cleaning works correctly and errors are handled gracefully."
    """
    print("🧪 Testing data loading function...")
    # Your AI-generated test cases go here
    pass

def test_spending_analysis():
    """
    Test spending analysis calculations

    🤖 AI Collaboration Prompt:
    "Create tests for spending analysis that verify:
    - Category totals are calculated correctly
    - Percentages add up to 100%
    - Refunds are handled appropriately
    - Edge cases like single transactions or empty categories
    Use assert statements with known expected results."
    """
    print("🧪 Testing spending analysis...")
    # Your AI-generated analysis tests go here
    pass

def test_business_insights():
    """
    Test business recommendation generation

    🤖 AI Collaboration Prompt:
    "Create tests that verify business insights are appropriate:
    - High spending categories are identified correctly
    - Savings opportunities are realistic
    - Recommendations match spending patterns
    - Output format is user-friendly"
    """
    print("🧪 Testing business insights...")
    # Your AI-generated insight tests go here
    pass

# Run all tests
print("🔍 COMPREHENSIVE TESTING SUITE")
print("=" * 40)

try:
    create_test_datasets()
    test_data_loading_function()
    test_spending_analysis()
    test_business_insights()
    print("✅ All tests passed! Your finance assistant is working correctly.")
except AssertionError as e:
    print(f"❌ Test failed: {e}")
except Exception as e:
    print(f"⚠️ Test error: {e}")
# Out:
# 🔍 COMPREHENSIVE TESTING SUITE
# ========================================
# 🧪 Testing data loading function...
# 🧪 Testing spending analysis...
# 🧪 Testing business insights...
# ✅ All tests passed! Your finance assistant is working correctly.

# %% [markdown]
# ## Advanced Integration Tests

# %%
# 🤖 AI Collaboration: Integration Testing
# Ask AI to help test the complete system integration

def test_full_workflow():
    """
    Test the complete workflow from CSV upload to final recommendations

    🤖 AI Collaboration Prompt:
    "Create an end-to-end test that:
    1. Loads sample CSV data
    2. Runs complete analysis pipeline
    3. Generates chat responses about the data
    4. Verifies RAG system retrieval
    5. Tests custom tool functionality
    Ensure all components work together seamlessly."
    """
    print("🧪 Testing complete workflow integration...")
    # Your AI-generated integration tests go here
    pass

def test_error_handling():
    """
    Test error handling and user experience

    🤖 AI Collaboration Prompt:
    "Create tests that verify error handling for:
    - Invalid file uploads
    - Network connection issues
    - Malformed data
    - User input validation
    Ensure error messages are user-friendly and helpful."
    """
    print("🧪 Testing error handling...")
    # Your AI-generated error tests go here
    pass

# Run integration tests
try:
    test_full_workflow()
    test_error_handling()
    print("✅ Integration tests completed successfully!")
except Exception as e:
    print(f"⚠️ Integration test issue: {e}")
# Out:
# 🧪 Testing complete workflow integration...
# 🧪 Testing error handling...
# ✅ Integration tests completed successfully!

# %% [markdown]
# ---
#
# # 📊 Project Completion Checklist
#
# ## Foundation Skills ✅
# - [ ] **Data Processing**: CSV loading and cleaning functions work reliably
# - [ ] **Analysis Functions**: Spending summaries calculate correctly
# - [ ] **Business Insights**: Recommendations are relevant and actionable
# - [ ] **Error Handling**: Graceful handling of data issues
# - [ ] **Testing**: Comprehensive test coverage for core functions
# - [ ] **Documentation**: Clear AI collaboration documentation in diary
#
# ## Advanced Integration ✅
# - [ ] **Chat Interface**: Finance advisor personality implemented
# - [ ] **RAG System**: Document retrieval for financial guidance
# - [ ] **Custom Tools**: At least one financial calculator/utility
# - [ ] **Gradio UI**: Professional, user-friendly interface
# - [ ] **Full Integration**: All components work together seamlessly
#
# ## Professional Standards ✅
# - [ ] **Code Quality**: Professional, commented, maintainable code
# - [ ] **Business Focus**: Clear connection to real finance problems
# - [ ] **User Experience**: Interface suitable for non-technical users
# - [ ] **AI Collaboration**: Extensive, well-documented AI usage
# - [ ] **Testing**: Robust validation of all features
#
# ## Project Documentation ✅
# - [ ] **Developer's Diary**: Complete AI collaboration documentation
# - [ ] **README**: Clear project description and usage instructions
# - [ ] **GitHub**: Regular commits showing development progress
# - [ ] **Reflection**: Thoughtful analysis of learning and challenges
#
# ---
#
# # 🎯 Final Thoughts: Your Finance Assistant Journey
#
# Congratulations on building your Smart Finance Assistant! This project represents a significant achievement in modern business programming:
#
# **Technical Skills Developed:**
# - AI-assisted development workflows
# - Professional data processing with pandas
# - Integration of multiple AI technologies
# - User interface design with Gradio
# - Comprehensive software testing
#
# **Business Skills Developed:**
# - Financial data analysis and insights
# - User-centered application design
# - Professional documentation practices
# - Iterative development methodology
# - Critical evaluation of AI suggestions
#
# **Professional Preparation:**
# - Experience with industry-standard AI collaboration
# - Portfolio-ready application development
# - Understanding of business problem-solving with technology
# - Documentation practices for workplace environments
#
# **Your Smart Finance Assistant demonstrates your ability to direct AI tools toward meaningful business solutions - exactly the skill set that modern BIS graduates need for career success!**
#
# ---
#
# *Remember to document all AI collaborations in your Developer's Diary and maintain regular GitHub commits throughout your development process.*
